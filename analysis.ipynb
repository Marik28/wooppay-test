# %%
import pandas as pd
import numpy as np

pd.options.display.max_rows = 1000

# %%
df = pd.read_csv("data/netflix.csv", parse_dates=["date_added"])

# %%
df.head(100)
# Out:
#      show_id     type                                              title  \
# 0   81145628    Movie            Norm of the North: King Sized Adventure
# 1   80117401    Movie                         Jandino: Whatever it Takes
# 2   70234439  TV Show                                 Transformers Prime
# 3   80058654  TV Show                   Transformers: Robots in Disguise
# 4   80125979    Movie                                       #realityhigh
# 5   80163890  TV Show                                            Apaches
# 6   70304989    Movie                                           Automata
# 7   80164077    Movie                 Fabrizio Copano: Solo pienso en mi
# 8   80117902  TV Show                                       Fire Chasers
# 9   70304990    Movie                                        Good People
# 10  80169755    Movie                        Joaquín Reyes: Una y no más
# 11  70299204    Movie                            Kidnapping Mr. Heineken
# ...

# %%
df[df["type"] == "Movie"]
# Out:
#        show_id   type                                    title  \
# 0     81145628  Movie  Norm of the North: King Sized Adventure
# 1     80117401  Movie               Jandino: Whatever it Takes
# 4     80125979  Movie                             #realityhigh
# 6     70304989  Movie                                 Automata
# 7     80164077  Movie       Fabrizio Copano: Solo pienso en mi
# ...        ...    ...                                      ...
# 5577  80085438  Movie                          Frank and Cindy
# 5578  80085439  Movie                          Frank and Cindy
# 5579  80011846  Movie                                  Iverson
# 5580  80064521  Movie      Jeremy Scott: The People's Designer
# 6231  80116008  Movie   Little Baby Bum: Nursery Rhyme Friends
#
#                              director  \
# 0            Richard Finn, Tim Maltby
# 1                                 NaN
# 4                    Fernando Lebrija
# 6                         Gabe Ibáñez
# ...

# %%
def split_strings(column: pd.Series, separator: str = ",") -> pd.Series:
    """Splits all strings and casts NaN's to empty lists"""
    return (
        column.fillna("")
            .apply(lambda value: value.strip(separator).split(separator) if value != "" else [])
            .apply(lambda values: [value.strip() for value in values])
    )

# %%
df['cast'] = split_strings(df['cast'])

# %%
df[df["cast"].isna()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
df['director'] = split_strings(df['director'])

# %%
df[df["director"].isna()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
df['country'] = split_strings(df['country'])

# %%
df[df["country"].isna()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
df['listed_in'] = split_strings(df['listed_in'])

# %%
df[df["listed_in"].isna()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
df['type'].unique()
# Out:
# array(['Movie', 'TV Show'], dtype=object)

# %%
df["listed_in"]
# Out:
# 0                    [Children & Family Movies, Comedies]
# 1                                       [Stand-Up Comedy]
# 2                                              [Kids' TV]
# 3                                              [Kids' TV]
# 4                                              [Comedies]
#                               ...
# 6229    [TV Action & Adventure, TV Comedies, TV Sci-Fi...
# 6230                                        [TV Comedies]
# 6231                                             [Movies]
# 6232           [British TV Shows, TV Comedies, TV Dramas]
# 6233                     [Classic & Cult TV, TV Comedies]
# Name: listed_in, Length: 6234, dtype: object

# %%
from typing import Iterable

def to_1D(series: Iterable) -> pd.Series:
    """Делает плоский массив из всех элементов переданных массивов"""
    return pd.Series([x for _list in series for x in _list])

# %%
genres = to_1D(df["listed_in"]).unique()

# %%
genres
# Out:
# array(['Children & Family Movies', 'Comedies', 'Stand-Up Comedy',
#        "Kids' TV", 'Crime TV Shows', 'International TV Shows',
#        'Spanish-Language TV Shows', 'International Movies',
#        'Sci-Fi & Fantasy', 'Thrillers', 'Docuseries',
#        'Science & Nature TV', 'Action & Adventure', 'Dramas',
#        'Cult Movies', 'Independent Movies', 'Romantic Movies',
#        'Documentaries', 'Horror Movies', 'Romantic TV Shows',
#        'TV Comedies', 'TV Dramas', 'TV Thrillers', 'TV Mysteries',
#        'British TV Shows', 'Music & Musicals', 'Reality TV',
#        'TV Action & Adventure', 'Anime Features', 'Teen TV Shows',
#        'Faith & Spirituality', 'Korean TV Shows', 'Anime Series',
#        'LGBTQ Movies', 'TV Horror', 'Movies',
#        'Stand-Up Comedy & Talk Shows', 'TV Sci-Fi & Fantasy',
#        'Classic Movies', 'Sports Movies', 'TV Shows', 'Classic & Cult TV'],
#       dtype=object)

# %%
df['duration'] = df['duration'].apply(lambda duration: int(duration.split(" ")[0]))

# %%
df["duration"]
# Out:
# 0       90
# 1       94
# 2        1
# 3        1
# 4       99
#         ..
# 6229    13
# 6230     4
# 6231    60
# 6232     2
# 6233    10
# Name: duration, Length: 6234, dtype: int64

# %%
df.tail(100)
# Out:
#        show_id     type                                        title  \
# 6134  80176929  TV Show                              Abnormal Summit
# 6135  80176931  TV Show                             Chef & My Fridge
# 6136  80194367  TV Show                          Paranormal Survivor
# 6137  80117552  TV Show                                        Ozark
# 6138  80223138  TV Show                            The Comedy Lineup
# 6139  80095299  TV Show                         Ultimate Beastmaster
# 6140  80156006  TV Show                  Ultimate Beastmaster México
# 6141  80211492  TV Show                          Mighty Little Bheem
# 6142  80063224  TV Show                The Great British Baking Show
# 6143  80063599  TV Show                 True and the Rainbow Kingdom
# 6144  80171452  TV Show                        Dinotrux Supercharged
# 6145  80198991  TV Show                                 Workin' Moms
# 6146  81029611  TV Show                   Droppin' Cash: Los Angeles
# ...

# %%
df.rating.dropna().unique()
# Out:
# array(['TV-PG', 'TV-MA', 'TV-Y7-FV', 'TV-Y7', 'TV-14', 'R', 'TV-Y', 'NR',
#        'PG-13', 'TV-G', 'PG', 'G', 'UR', 'NC-17'], dtype=object)

# %%
df.count()
# Out:
# show_id         6234
# type            6234
# title           6234
# director        6234
# cast            6234
# country         6234
# date_added      6223
# release_year    6234
# rating          6224
# duration        6234
# listed_in       6234
# description     6234
# dtype: int64
